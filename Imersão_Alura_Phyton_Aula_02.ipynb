# %% [markdown]
# Aula 02 - Importação

# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/Imersão Python - Tabela de ações_Aula02.xlsx",sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ... Variação 12M %  \
# 0           2.26         15.97      9.18      9.56  ...         0.1597
# 1         -12.11         50.56      6.66      6.86  ...         0.5056
# 2           7.64         77.55     40.81     42.34  ...         0.7755
# 3          -4.89         18.85     51.89     53.17  ...         0.1885
# 4          -3.66         20.70     36.37     37.32  ...         0.2070
# ..           ...           ...       ...       ...  ...            ...
# 76        -13.98        -32.72     10.70     11.08  ...        -0.3272
# 77        -23.55        -85.74      8.67      8.95  ...        -0.8574
# 78        -11.57         -2.77     56.04     58.90  ...        -0.0277
# 79        -12.29        -36.83      3.05      3.23  ...        -0.3683
# 80        -34.00        -25.44      5.51      6.02  ...        -0.2544
#
#     Valor Inicial (R$)  Variação R$.4  Resultado.4  Unnamed: 39 Idade CHATGPT  \
# 0             8.191774   6.738901e+08        Subiu          NaN            64
# 1             4.529756   2.543452e+09        Subiu          NaN            70
# 2            23.632780   4.361654e+10        Subiu          NaN            69
# 3            44.518300   5.735331e+09        Subiu          NaN            99
# 4            30.737365   1.194474e+09        Subiu          NaN           109
# ..                 ...            ...          ...          ...           ...
# 76           15.918549  -2.781316e+09       Desceu          NaN            47
# 77           61.009818  -4.961222e+09       Desceu          NaN            70
# 78           57.842230  -1.367026e+09       Desceu          NaN            49
# 79            4.859902  -9.407416e+08       Desceu          NaN            48
# 80            7.939914  -4.003165e+08       Desceu          NaN            22
#
#    Faixa de idade CHATGPT Unnamed: 42  Faixa de idade CHATGPT (Código)  \
# 0     Entre 50 e 100 anos         NaN              Entre 50 e 100 anos
# 1     Entre 50 e 100 anos         NaN              Entre 50 e 100 anos
# 2     Entre 50 e 100 anos         NaN              Entre 50 e 100 anos
# 3     Entre 50 e 100 anos         NaN              Entre 50 e 100 anos
# 4       Acima de 100 anos         NaN                Acima de 100 anos
# ..                    ...         ...                              ...
# 76            Até 50 anos         NaN                      Até 50 anos
# 77    Entre 50 e 100 anos         NaN              Entre 50 e 100 anos
# 78            Até 50 anos         NaN                      Até 50 anos
# 79            Até 50 anos         NaN                      Até 50 anos
# 80            Até 50 anos         NaN                      Até 50 anos
#
#                                    Formula do ChatGPT
# 0   Você pode usar a seguinte fórmula na célula AL...
# 1                                     excelCopy code
# 2   IF(AO3 <= 50, "Até 50 anos", IF(AND(AO3  > 50,...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
#
# [81 rows x 45 columns]

# %%
df_total_de_acoes = pd.read_excel("/Imersão Python - Tabela de ações_Aula02.xlsx",sheet_name="Total_de_acoes")
df_total_de_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/Imersão Python - Tabela de ações_Aula02.xlsx",sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/Imersão Python - Tabela de ações_Aula02.xlsx",sheet_name="Chatgpt")
df_chatgpt
# Out:
#      Nome da Empresa           Segmento  Idade (anos)
# 0           Usiminas         Siderurgia            59
# 1      CSN Mineração          Mineração            81
# 2          Petrobras           Petróleo            69
# 3             Suzano   Papel e Celulose            98
# 4       CPFL Energia            Energia           109
# ..               ...                ...           ...
# 76  Carrefour Brasil             Varejo            46
# 77       Casas Bahia             Varejo            68
# 78          Localiza  Aluguel de Carros            49
# 79               CVC            Turismo            49
# 80               GOL   Transporte Aéreo            21
#
# [81 rows x 3 columns]
